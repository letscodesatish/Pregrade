# %%
def emp_info():
    i=0
    while i<5:
        name=input("Enter your name")
        age=int(input("Enter your age"))
        designation=input("Enter your designation")
        print(f'My name is {name}.I am {age} years old and I am a {designation}')
        i=i+1
emp_info()
# Out:
# Enter your name Satish kumar sharma
# Enter your age 19
# Enter your designation Web developer
# My name is Satish kumar sharma.I am 19 years old and I am a Web developer
# Enter your name Aakshant Kumar
# Enter your age 20
# Enter your designation Data Scientist
# My name is Aakshant Kumar.I am 20 years old and I am a Data Scientist
# Enter your name Prashant Singh
# Enter your age 24
# Enter your designation Cloud Engineer
# My name is Prashant Singh.I am 24 years old and I am a Cloud Engineer
# Enter your name Anurag Yadav
# Enter your age 23
# Enter your designation Ai engineer
# My name is Anurag Yadav.I am 23 years old and I am a Ai engineer
# Enter your name Japneet
# Enter your age 28
# Enter your designation Data consultant
# My name is Japneet.I am 28 years old and I am a Data consultant
