# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
lst=[1,2,3,4,5]
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(lst))
lst.ndim
# Out:
# <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 print(type(lst))
# ----> 2 lst.ndim
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
arr=np.array([11,22,33,44,55])
arr

# %%
print(type(arr))

# %%
arr.ndim

# %% [markdown]
# # Difference between array and list

# %% [markdown]
# # diff 1

# %%
lst=[1,"satish",True,2.8]
lst

# %%
arr=np.array([1,2,3,4,5])
arr

# %%
arr=np.array([1,"satish",4.6])
arr

# %% [markdown]
# # diff 2

# %%
lst=[1,2,3,4,5]
lst

# %%
lst=[1,2,3,4,5]*5
lst

# %%
lst=[1,2,3,4,5]

# %%
l=[]
for i in lst:
    i=i*5
    l.append(i)
print(l)

# %%
arr=np.array([1,2,3,4,5])
arr

# %%
arr=np.array([1,2,3,4,5])*5
print(arr)

# %%
arr=np.array([1,2,3,4,5])+5
print(arr)

# %% [markdown]
# # diff 3

# %%
[ i for i in range(1,6)]

# %%
[ i**2 for i in range(1,6)]

# %%
# %timeit [ i**2 for i in range(1,6)]

# %%
# %timeitnp.arange(1,6)**2

# %%
# %timeit [ i**2 for i in range(1,600)]

# %%
# %timeit np.arange(1,600)**2

# %% [markdown]
# # 1D,2D and 3D Array

# %% [markdown]
# # 1D Array

# %%
arr=np.array([1,2,3,4,5])
arr

# %%
arr.shape

# %%
arr.ndim

# %% [markdown]
# # 2D Array

# %%
arr1=np.array([[1,2,3,4,5]])
print(arr1)

# %%
arr1.shape

# %%
arr1.ndim

# %%
arr2=np.array([[1,2,3],[44,55,66]])
print(arr2)

# %% [markdown]
# # 3D Array

# %%
arr3=np.array([[[1,2,3,4,5]]])
print(arr3)

# %%
arr3.ndim

# %%
arr3.shape

# %%
arr=np.array([[[1,2],[34,67]],[[4,5],[21,34]],[[66,88],[31,67]]])
arr

# %%
arr.shape

# %%
arr=np.array([1,2,3,4,5],ndmin=10)

# %%
print(arr)

# %%
arr.shape

# %%
arr=np.array([1,2,3,4,5],ndmin=32)
print(arr)

# %% [markdown]
# # Special Numpy Function

# %%
np.zeros(5)

# %%
np.zeros([5,4],dtype=int)

# %%
np.zeros([2,3,4],dtype=int)

# %%
np.ones(5,dtype=int)

# %%
np.ones([2,3],dtype=int)

# %%
np.ones([1,2,3],dtype=int)

# %%
np.full(5,2)

# %%
np.full([2,3],5)

# %%
np.full([2,3],5.3)

# %%
np.full([2,3],5.3,dtype=str)

# %%
np.arange(1,11)

# %%
np.arange(0,100,5)

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
lst=[4,5,6,3,1]
lst

# %%
ser=pd.Series(lst)
ser

# %%
type(ser)

# %%
ser=pd.Series([1,2,34,5,6],index=["a","b","c","d","e"])
ser

# %%
ser=pd.Series([1,2,34,5,6],index=["a","b","c","d","e"],name="Rating")
ser

# %% [markdown]
# # Dataframe

# %% [markdown]
# __Using List__

# %%
lst=[["apple",5],["mango",10],["banana",15]]
lst

# %%
df=pd.DataFrame(lst)
df

# %%
df=pd.DataFrame(lst,columns=["Fruits","Quantity"])
df

# %%
lst=[["apple",5,"L"],["mango",10,"D"],["banana",15,"L"]]
df=pd.DataFrame(lst,columns=["Fruits","Quantity","L/D"])
df

# %%
type(df)

# %%
import numpy as np

# %%
lst=[["apple",5,"L"],["mango",np.nan,"D"],["banana",15,"L"]]
df=pd.DataFrame(lst,columns=["Fruits","Quantity","L/D"])
df

# %% [markdown]
# __Using Dictionary__

# %%
fruits={
    "fruits":["apple","banana","mango","orange"],
    "quantity":[12,15,16,10],
    "like/dislike":["L","D","L","D"]
}
df=pd.DataFrame(fruits)
df

# %%
df.shape

# %%
df.ndim

# %%
df["fruits"]

# %%
df.fruits

# %%
df["fruits","like/dislike"]

# %%
df[["fruits","like/dislike"]]

# %% [markdown]
# # Arithmatic Operation

# %%
df=pd.DataFrame(
    {
        "A":[1,2,3,4,5],
        "B":[7,8,4,2,1]
    }
)
df

# %%
df["A"]

# %%
df["C"]=df["A"]+df["B"]

# %%
df

# %%
del df["c"]

# %%
df

# %%
df["D"]=df["A"]*df["B"]

# %%
df

# %% [markdown]
# __Insert and delete__

# %%
df.insert(0,"Alphabets",["a","b","c","d","e"])

# %%
df

# %%
d=df.copy()

# %%
f=df

# %%
print(d)
print()
print(f)

# %%
del df["A"]

# %%
df

# %%
del df

# %%
df

# %%
df=d

# %%
df

# %% [markdown]
# # Load the database

# %%
df=pd.read_csv("petrol_consumption.csv")
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# 11        7.50          5126.0             NaN                         0.525
# 12        7.00          4817.0          6930.0                         0.574
# 13        7.00          4207.0          6580.0                         0.545
# 14        7.00          4332.0          8159.0                           NaN
# 15        7.00          4318.0         10340.0                         0.586
# 16        7.00          4206.0             NaN                         0.572
# 17        7.00          3718.0          4725.0                         0.540
# 18        7.00             NaN          5915.0                         0.724
# 19        8.50          4341.0          6010.0                         0.677
# 20        7.00             NaN          7834.0                         0.663
# 21        8.00          4983.0           602.0                         0.602
# 22        9.00          4897.0          2449.0                         0.511
# 23        9.00          4258.0          4686.0                         0.517
# 24        8.50          4574.0          2619.0                         0.551
# 25        9.00          3721.0          4746.0                         0.544
# 26        8.00          3448.0          5399.0                         0.548
# 27        7.50          3846.0          9061.0                         0.579
# 28        8.00          4188.0          5975.0                         0.563
# 29        9.00          3601.0             NaN                         0.493
# 30        7.00          3640.0          6905.0                         0.518
# 31        7.00          3333.0          6594.0                         0.513
# 32        8.00          3063.0          6524.0                         0.578
# 33        7.50          3357.0          4121.0                         0.547
# 34        8.00             NaN          3495.0                         0.487
# 35        6.58          3802.0          7834.0                         0.629
# 36        5.00          4045.0             NaN                         0.566
# 37        7.00          3897.0          6385.0                         0.586
# 38        8.50          3635.0          3274.0                         0.663
# 39        7.00          4345.0          3905.0                         0.672
# 40        7.00          4449.0          4639.0                         0.626
# 41        7.00             NaN          3985.0                         0.563
# 42        7.00          4300.0          3635.0                         0.603
# 43        7.00          3745.0          2611.0                         0.508
# 44        6.00          5215.0          2302.0                         0.672
# 45        9.00          4476.0          3942.0                         0.571
# 46        7.00          4296.0          4083.0                         0.623
# 47        7.00          5002.0          9794.0                         0.593
#
#     Petrol_Consumption
# 0                541.0
# 1                524.0
# 2                561.0
# 3                  NaN
# 4                410.0
# 5                457.0
# 6                344.0
# 7                467.0
# 8                464.0
# 9                498.0
# 10               580.0
# 11                 NaN
# 12               525.0
# 13               508.0
# 14               566.0
# 15               635.0
# 16               603.0
# 17               714.0
# 18               865.0
# 19               640.0
# 20               649.0
# 21               540.0
# 22               464.0
# 23               547.0
# 24               460.0
# 25               566.0
# 26               577.0
# 27               631.0
# 28               574.0
# 29               534.0
# 30               571.0
# 31               554.0
# 32               577.0
# 33               628.0
# 34               487.0
# 35               644.0
# 36               640.0
# 37               704.0
# 38               648.0
# 39               968.0
# 40               587.0
# 41               699.0
# 42               632.0
# 43               591.0
# 44               782.0
# 45               510.0
# 46               610.0
# 47               524.0

# %% [markdown]
# __Basic Exploratory Data Analysis (EDA)__

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
# df.describe(include="object")

# %%
df.head(4)

# %%
df.tail()

# %% [markdown]
# __Indexing and Slicing__
# - iloc[] and loc[]

# %%
df.iloc[3]

# %%
df.iloc[0:48,0:5]

# %%
df.iloc[:,:]

# %%
df.iloc[:5,:3]

# %%
df.iloc[4:11,2:]

# %%
df.iloc[4:11,:5:2]

# %%
# loc[]

# %%
df.loc[4:11,["Petrol_tax","Average_income","Petrol_Consumption"]]

# %%
df[["Petrol_tax","Average_income","Petrol_Consumption"]][4:11]

# %%
df[["Petrol_tax","Average_income","Petrol_Consumption"]].index

# %%
df[df["Petrol_tax"]==9.00]

# %%
df[df["Petrol_tax"]==9.00].index

# %% [markdown]
# __Unique Value Identification__
# - nunique()
# - unique()
# - value_counts()

# %%
df.nunique()

# %%
df["Petrol_tax"].nunique()

# %%
df["Petrol_tax"].unique()

# %%
df["Petrol_tax"].value_counts()

# %%
df["Petrol_tax"].mean()

# %%
df["Petrol_tax"].median()

# %%
df["Petrol_tax"].mode()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(df["Petrol_tax"],bins=30,color="r",label=f"skewness : {round(df["Petrol_tax"].skew(),2)}")
plt.legend()
plt.show()

# %% [markdown]
# # Missing Data
# - filna()
# - dropna()

# %%
df

# %%
df.isnull()

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
df.isnull().mean()*100

# %%
df.fillna(888888888)

# %%
df["Average_income"].mean()

# %%
df["Average_income"].median()

# %%
sns.distplot(df["Average_income"],bins=30,color="k",label=f"skewness: {round(df["Average_income"].skew(),2)}")
plt.legend()
plt.show()

# %%
df["Average_income"].fillna(df["Average_income"].mean())

# %%
df["Average_income"].fillna(df["Average_income"].mean(),inplace=True)

# %%
df

# %%
df.isnull().sum()

# %%
df.dropna()

# %%
df.shape

# %%
df.dropna(inplace=True)

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.isna().sum()

# %% [markdown]
# # Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Petrol_tax, Average_income, Paved_Highways, Population_Driver_licence(%), Petrol_Consumption]
# Index: []

# %% [markdown]
# # Drop()

# %%
df
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00          3571.0          1976.0                         0.525
# 1         9.00          4092.0          1250.0                         0.572
# 2         9.00             NaN             NaN                         0.580
# 3         7.50          4870.0          2351.0                         0.529
# 4         8.00          4399.0           431.0                         0.544
# 5        10.00          5342.0          1333.0                         0.571
# 6         8.00          5319.0         11868.0                         0.451
# 7         8.00          5126.0          2138.0                         0.553
# 8         8.00          4447.0          8577.0                         0.529
# 9         7.00          4512.0          8507.0                         0.552
# 10        8.00          4391.0          5939.0                         0.530
# 11        7.50          5126.0             NaN                         0.525
# 12        7.00          4817.0          6930.0                         0.574
# 13        7.00          4207.0          6580.0                         0.545
# 14        7.00          4332.0          8159.0                           NaN
# 15        7.00          4318.0         10340.0                         0.586
# 16        7.00          4206.0             NaN                         0.572
# 17        7.00          3718.0          4725.0                         0.540
# 18        7.00             NaN          5915.0                         0.724
# 19        8.50          4341.0          6010.0                         0.677
# 20        7.00             NaN          7834.0                         0.663
# 21        8.00          4983.0           602.0                         0.602
# 22        9.00          4897.0          2449.0                         0.511
# 23        9.00          4258.0          4686.0                         0.517
# 24        8.50          4574.0          2619.0                         0.551
# 25        9.00          3721.0          4746.0                         0.544
# 26        8.00          3448.0          5399.0                         0.548
# 27        7.50          3846.0          9061.0                         0.579
# 28        8.00          4188.0          5975.0                         0.563
# 29        9.00          3601.0             NaN                         0.493
# 30        7.00          3640.0          6905.0                         0.518
# 31        7.00          3333.0          6594.0                         0.513
# 32        8.00          3063.0          6524.0                         0.578
# 33        7.50          3357.0          4121.0                         0.547
# 34        8.00             NaN          3495.0                         0.487
# 35        6.58          3802.0          7834.0                         0.629
# 36        5.00          4045.0             NaN                         0.566
# 37        7.00          3897.0          6385.0                         0.586
# 38        8.50          3635.0          3274.0                         0.663
# 39        7.00          4345.0          3905.0                         0.672
# 40        7.00          4449.0          4639.0                         0.626
# 41        7.00             NaN          3985.0                         0.563
# 42        7.00          4300.0          3635.0                         0.603
# 43        7.00          3745.0          2611.0                         0.508
# 44        6.00          5215.0          2302.0                         0.672
# 45        9.00          4476.0          3942.0                         0.571
# 46        7.00          4296.0          4083.0                         0.623
# 47        7.00          5002.0          9794.0                         0.593
#
#     Petrol_Consumption
# 0                541.0
# 1                524.0
# 2                561.0
# 3                  NaN
# 4                410.0
# 5                457.0
# 6                344.0
# 7                467.0
# 8                464.0
# 9                498.0
# 10               580.0
# 24        8.50          4574.0          2619.0                         0.551
# 25        9.00          3721.0          4746.0                         0.544
# 26        8.00          3448.0          5399.0                         0.548
# 27        7.50          3846.0          9061.0                         0.579
# 28        8.00          4188.0          5975.0                         0.563
# 29        9.00          3601.0             NaN                         0.493
# 30        7.00          3640.0          6905.0                         0.518
# 31        7.00          3333.0          6594.0                         0.513
# 32        8.00          3063.0          6524.0                         0.578
# 33        7.50          3357.0          4121.0                         0.547
# 34        8.00             NaN          3495.0                         0.487
# 35        6.58          3802.0          7834.0                         0.629
# 36        5.00          4045.0             NaN                         0.566
# 37        7.00          3897.0          6385.0                         0.586
# 38        8.50          3635.0          3274.0                         0.663
# 39        7.00          4345.0          3905.0                         0.672
# 40        7.00          4449.0          4639.0                         0.626
# 41        7.00             NaN          3985.0                         0.563
# 42        7.00          4300.0          3635.0                         0.603
# 43        7.00          3745.0          2611.0                         0.508
# 44        6.00          5215.0          2302.0                         0.672
# 45        9.00          4476.0          3942.0                         0.571
# 46        7.00          4296.0          4083.0                         0.623
# 47        7.00          5002.0          9794.0                         0.593

# %% [markdown]
# # Concat() and Merge()
# - Concat()

# %%
df1=pd.DataFrame({"A":[1,2,3,4,5],"B":[11,22,33,44,55]})
df2=pd.DataFrame({"C":[11,12,13,14,15],"D":[101,202,303,404,505]})

# %%
print(df1)
print(df2)
# Out:
#    A   B
# 0  1  11
# 1  2  22
# 2  3  33
# 3  4  44
# 4  5  55
#     C    D
# 0  11  101
# 1  12  202
# 2  13  303
# 3  14  404
# 4  15  505

# %%
pd.concat([df1,df2])
# Out:
#      A     B     C      D
# 0  1.0  11.0   NaN    NaN
# 1  2.0  22.0   NaN    NaN
# 2  3.0  33.0   NaN    NaN
# 3  4.0  44.0   NaN    NaN
# 4  5.0  55.0   NaN    NaN
# 0  NaN   NaN  11.0  101.0
# 1  NaN   NaN  12.0  202.0
# 2  NaN   NaN  13.0  303.0
# 3  NaN   NaN  14.0  404.0
# 4  NaN   NaN  15.0  505.0

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#      A     B     C      D
# 0  1.0  11.0   NaN    NaN
# 1  2.0  22.0   NaN    NaN
# 2  3.0  33.0   NaN    NaN
# 3  4.0  44.0   NaN    NaN
# 4  5.0  55.0   NaN    NaN
# 5  NaN   NaN  11.0  101.0
# 6  NaN   NaN  12.0  202.0
# 7  NaN   NaN  13.0  303.0
# 8  NaN   NaN  14.0  404.0
# 9  NaN   NaN  15.0  505.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    A   B   C    D
# 0  1  11  11  101
# 1  2  22  12  202
# 2  3  33  13  303
# 3  4  44  14  404
# 4  5  55  15  505

# %% [markdown]
# # Merge()

# %%
df1=pd.DataFrame({"A":[1,2,3],"B":[11,22,33]})
df2=pd.DataFrame({"A":[11,2,3],"C":[101,202,303]})

# %%
df2.merge(df1,on="A")
# Out:
#    A    C   B
# 0  2  202  22
# 1  3  303  33

# %% [markdown]
# # GroupBy() Function

# %%
data=pd.read_csv("emp_data.csv")

# %%
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data.nunique()
# Out:
# Emp_id    100
# Name      100
# City        4
# Salary    100
# dtype: int64

# %%
data["City"].unique()
# Out:
# array(['Noida', 'Banglore', 'Pune', 'Gurgaon'], dtype=object)

# %%
data["City"].value_counts()
# Out:
# City
# Gurgaon     35
# Noida       30
# Banglore    18
# Pune        17
# Name: count, dtype: int64

# %%
data.groupby("City")

# %%
noida=data.groupby("City").get_group("Noida")
noida
# Out:
#     Emp_id    Name   City  Salary
# 0        1   Emp_1  Noida   76252
# 2        3   Emp_3  Noida   73672
# 9       10  Emp_10  Noida   66920
# 11      12  Emp_12  Noida   68936
# 13      14  Emp_14  Noida   92541
# 18      19  Emp_19  Noida   43908
# 21      22  Emp_22  Noida   71302
# 33      34  Emp_34  Noida   96846
# 36      37  Emp_37  Noida   98538
# 42      43  Emp_43  Noida   88075
# 44      45  Emp_45  Noida   58527
# 46      47  Emp_47  Noida   48400
# 47      48  Emp_48  Noida   46042
# 49      50  Emp_50  Noida   52329
# 51      52  Emp_52  Noida   71335
# 53      54  Emp_54  Noida   52683
# 59      60  Emp_60  Noida   45004
# 61      62  Emp_62  Noida   86583
# 62      63  Emp_63  Noida   90083
# 64      65  Emp_65  Noida   45905
# 66      67  Emp_67  Noida   48382
# 67      68  Emp_68  Noida   77912
# 74      75  Emp_75  Noida   86643
# 77      78  Emp_78  Noida   93787
# 82      83  Emp_83  Noida   74060
# 84      85  Emp_85  Noida   51840
# 85      86  Emp_86  Noida   74826
# 87      88  Emp_88  Noida   91586
# 94      95  Emp_95  Noida   88315
# 96      97  Emp_97  Noida   60635

# %%
noida.shape
# Out:
# (30, 4)

# %%
noida["Salary"].min()
# Out:
# 43908

# %%
noida[noida.Salary== 43908]
# Out:
#     Emp_id    Name   City  Salary
# 18      19  Emp_19  Noida   43908

# %%
noida["Salary"].max()
# Out:
# 98538

# %%
noida["Salary"].mean()
# Out:
# 70728.9

# %%
noida[noida.Salary<70728.9]
# Out:
#     Emp_id    Name   City  Salary
# 9       10  Emp_10  Noida   66920
# 11      12  Emp_12  Noida   68936
# 18      19  Emp_19  Noida   43908
# 44      45  Emp_45  Noida   58527
# 46      47  Emp_47  Noida   48400
# 47      48  Emp_48  Noida   46042
# 49      50  Emp_50  Noida   52329
# 53      54  Emp_54  Noida   52683
# 59      60  Emp_60  Noida   45004
# 64      65  Emp_65  Noida   45905
# 66      67  Emp_67  Noida   48382
# 84      85  Emp_85  Noida   51840
# 96      97  Emp_97  Noida   60635

# %%
len(noida[noida.Salary<70728.9])
# Out:
# 13

# %%
noida[noida.Salary<70728.9].Salary
# Out:
# 9     66920
# 11    68936
# 18    43908
# 44    58527
# 46    48400
# 47    46042
# 49    52329
# 53    52683
# 59    45004
# 64    45905
# 66    48382
# 84    51840
# 96    60635
# Name: Salary, dtype: int64

# %%
noida[noida.Salary<70728.9][["Emp_id","Salary"]].values
# Out:
# array([[   10, 66920],
#        [   12, 68936],
#        [   19, 43908],
#        [   45, 58527],
#        [   47, 48400],
#        [   48, 46042],
#        [   50, 52329],
#        [   54, 52683],
#        [   60, 45004],
#        [   65, 45905],
#        [   67, 48382],
#        [   85, 51840],
#        [   97, 60635]], dtype=int64)

# %%
noida[noida.Salary<70728.9]["Salary"].index
# Out:
# Index([9, 11, 18, 44, 46, 47, 49, 53, 59, 64, 66, 84, 96], dtype='int64')

# %% [markdown]
# # Set_index() and Reset_index()

# %%
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data.set_index("Emp_id",inplace=True)

# %%
data
# Out:
#            Name      City  Salary
# Emp_id
# 1         Emp_1     Noida   76252
# 2         Emp_2  Banglore   60315
# 3         Emp_3     Noida   73672
# 4         Emp_4      Pune   46501
# 5         Emp_5  Banglore   68611
# ...         ...       ...     ...
# 96       Emp_96  Banglore   60006
# 97       Emp_97     Noida   60635
# 98       Emp_98   Gurgaon   51311
# 99       Emp_99      Pune   89409
# 100     Emp_100   Gurgaon   92971
#
# [100 rows x 3 columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %% [markdown]
# # sort_values()

# %%
data
# Out:
#     Emp_id     Name      City  Salary
# 0        1    Emp_1     Noida   76252
# 1        2    Emp_2  Banglore   60315
# 2        3    Emp_3     Noida   73672
# 3        4    Emp_4      Pune   46501
# 4        5    Emp_5  Banglore   68611
# ..     ...      ...       ...     ...
# 95      96   Emp_96  Banglore   60006
# 96      97   Emp_97     Noida   60635
# 97      98   Emp_98   Gurgaon   51311
# 98      99   Emp_99      Pune   89409
# 99     100  Emp_100   Gurgaon   92971
#
# [100 rows x 4 columns]

# %%
data.sort_values("Salary")
# Out:
#     Emp_id    Name      City  Salary
# 88      89  Emp_89   Gurgaon   43883
# 18      19  Emp_19     Noida   43908
# 5        6   Emp_6  Banglore   44646
# 25      26  Emp_26  Banglore   44710
# 59      60  Emp_60     Noida   45004
# ..     ...     ...       ...     ...
# 77      78  Emp_78     Noida   93787
# 6        7   Emp_7  Banglore   95408
# 35      36  Emp_36   Gurgaon   95851
# 33      34  Emp_34     Noida   96846
# 36      37  Emp_37     Noida   98538
#
# [100 rows x 4 columns]

# %%
data.sort_values("Salary",ascending=False)
# Out:
#     Emp_id    Name      City  Salary
# 36      37  Emp_37     Noida   98538
# 33      34  Emp_34     Noida   96846
# 35      36  Emp_36   Gurgaon   95851
# 6        7   Emp_7  Banglore   95408
# 77      78  Emp_78     Noida   93787
# ..     ...     ...       ...     ...
# 59      60  Emp_60     Noida   45004
# 25      26  Emp_26  Banglore   44710
# 5        6   Emp_6  Banglore   44646
# 18      19  Emp_19     Noida   43908
# 88      89  Emp_89   Gurgaon   43883
#
# [100 rows x 4 columns]

# %% [markdown]
# # Map() and apply()

# %%
data["City"]
# Out:
# 0        Noida
# 1     Banglore
# 2        Noida
# 3         Pune
# 4     Banglore
#         ...
# 95    Banglore
# 96       Noida
# 97     Gurgaon
# 98        Pune
# 99     Gurgaon
# Name: City, Length: 100, dtype: object

# %%
data["City"]=data["City"].map({"Gurgaon":0,"Noida":1,"Pune":2,"Banglore":3})

# %%
data
# Out:
#     Emp_id     Name  City  Salary
# 0        1    Emp_1     1   76252
# 1        2    Emp_2     3   60315
# 2        3    Emp_3     1   73672
# 3        4    Emp_4     2   46501
# 4        5    Emp_5     3   68611
# ..     ...      ...   ...     ...
# 95      96   Emp_96     3   60006
# 96      97   Emp_97     1   60635
# 97      98   Emp_98     0   51311
# 98      99   Emp_99     2   89409
# 99     100  Emp_100     0   92971
#
# [100 rows x 4 columns]

# %%
data["Name"].dtype
# Out:
# dtype('O')

# %%
data["Name"].apply(lambda x: x.replace("_","-"))
# Out:
# 0       Emp-1
# 1       Emp-2
# 2       Emp-3
# 3       Emp-4
# 4       Emp-5
#        ...
# 95     Emp-96
# 96     Emp-97
# 97     Emp-98
# 98     Emp-99
# 99    Emp-100
# Name: Name, Length: 100, dtype: object

# %%
data["Updated_Name"]=data["Name"].apply(lambda x: x.replace("_","-"))

# %%
data
# Out:
#     Emp_id     Name  City  Salary Updated_Name
# 0        1    Emp_1     1   76252        Emp-1
# 1        2    Emp_2     3   60315        Emp-2
# 2        3    Emp_3     1   73672        Emp-3
# 3        4    Emp_4     2   46501        Emp-4
# 4        5    Emp_5     3   68611        Emp-5
# ..     ...      ...   ...     ...          ...
# 95      96   Emp_96     3   60006       Emp-96
# 96      97   Emp_97     1   60635       Emp-97
# 97      98   Emp_98     0   51311       Emp-98
# 98      99   Emp_99     2   89409       Emp-99
# 99     100  Emp_100     0   92971      Emp-100
#
# [100 rows x 5 columns]
