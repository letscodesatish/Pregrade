# %%
cust_pin=123456
print("Please insert your card")
print("Press 1 for Deposit")
print("Press 2 for Withdrawal ")
operation = int(input("Enter your Operation: "))
if operation == 1 :
            a=int(input("Enter your pin"))
            if a==cust_pin:
                 print("Put your money into the slot of machine")
            else:
                 print("Pin is incorrect")        
elif operation== 2:
    a=int(input("Enter your pin"))
    if a==cust_pin:
    b=int(input("Enter your amount"))
    print("Please collect your money")
    print("Thank You!!!")
    else:
    print("Pin is incorrect")
else:
    print("Please enter the right operation")
# Out:
# Please insert your card
# Press 1 for Deposit
# Press 2 for Withdrawal
# Enter your Operation:  1
# Enter your pin 123567
# Pin is incorrect
